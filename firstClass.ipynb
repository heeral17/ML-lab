# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("notepad.csv")

# %%
data
# Out:
#    example  income credit score employment collature loan approval
# 0        1    high         good        yes       yes           yes
# 1        2    high          bad         no        no            no
# 2        3  medium         good         no       yes            no
# 3        4    high          bad        yes       yes           yes

# %%
concept = np.array(data)[:,:-1]

# %%
concept
# Out:
# array([[1, 'high', 'good', 'yes', 'yes'],
#        [2, 'high', 'bad', 'no', 'no'],
#        [3, 'medium', 'good', 'no', 'yes'],
#        [4, 'high', 'bad', 'yes', 'yes']], dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array(['yes', 'no', 'no', 'yes'], dtype=object)

# %%
def train(con,tar):
    for i,val in enumerate(tar):
     if val == "yes":
        specific_h = con[i].copy()
        break

    for i,val in enumerate(con):
        if tar[i] == "yes":
            for x in range(len(specific_h)):
                if val[x] != specific_h[x]:
                    specific_h[x] = "?"
                else:
                    pass
                    
    return specific_h

# %%
print(train(concept,target))
# Out:
# ['?' 'high' '?' 'yes' 'yes']
